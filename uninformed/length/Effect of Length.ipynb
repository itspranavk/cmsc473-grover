# %%
import json

f = open("mix1_out.jsonl")
data = json.load(f)
data
# Out:
# {'url': 'https://techcrunch.com/2019/04/19/malwaretech-legal-case-over/',
#  'url_used': 'https://web.archive.org/web/20190424064330id_/https://techcrunch.com/2019/04/19/malwaretech-legal-case-over/',
#  'title': 'Malware researcher Marcus Hutchins pleads guilty, ending his legal case – TechCrunch',
# ...

# %%
#original real article
real = data["text"]
real
# Out:
# 'Malware researcher Marcus Hutchins has pleaded guilty to two counts of creating and selling a powerful banking malware, ending a long and protracted battle with U.S. prosecutors.\nHutchins, a British national who goes by the online handle MalwareTech, was arrested in August 2017 as he was due to fly back to the U.K. following the Def Con security conference in Las Vegas. Prosecutors charged Hutchins with his involvement with creating the Kronos banking malware, dating back to 2014. He was later freed on bail.\nA plea agreement was filed with the Eastern District of Wisconsin, where the case was being heard on Friday. His trial was set to begin later this year.\nHutchins agreed to plead guilty to distributing Kronos, a trojan that can be used to steal passwords and credentials from banking websites. In recent years, the trojan has continued to spread. He also agreed to plead guilty to a second count of conspiracy.\nHutchins faces up to 10 years in prison. Prosecutors have dropped the
# ...

# %%
#fake article generated
fake = data["gens_article"][0]
fake
# Out:
# 'Malware researcher Marcus Hutchins, who has been battling the FDA over his right to share top-level security information, has pleaded guilty to a charge related to software designed to spread malware.\nHutchins will spend two years and six months in prison for violating the Computer Fraud and Abuse Act, US Attorney Jeffery Castro announced.\nAs part of the plea deal, the nature of the malware found on Hutchins’ computer has been redacted. To get around what is known as Hutchins’ A.I. defense, Google is allowing the Department of Justice to redact the information.\nAn offer he initially made to the FDA then backed out of, according to Assistant US Attorney Micheal Furnall, was essentially a $75,000 fine and a one-year jail sentence on a serious bias crime charge, Furnall said. If Hutchins had failed to comply with the deal, he’d face 30 years in prison, and he was sentenced to five years of supervised release, Furnall said.\n“In all of these federal cases the defendant agreed to abid
# ...

# %%
#splitting real article by \n
from nltk import tokenize

print("REAL:")
split_real = tokenize.sent_tokenize(real)
split_real
# Out:
# REAL:
# ['Malware researcher Marcus Hutchins has pleaded guilty to two counts of creating and selling a powerful banking malware, ending a long and protracted battle with U.S. prosecutors.',
#  'Hutchins, a British national who goes by the online handle MalwareTech, was arrested in August 2017 as he was due to fly back to the U.K. following the Def Con security conference in Las Vegas.',
#  'Prosecutors charged Hutchins with his involvement with creating the Kronos banking malware, dating back to 2014.',
#  'He was later freed on bail.',
#  'A plea agreement was filed with the Eastern District of Wisconsin, where the case was being heard on Friday.',
#  'His trial was set to begin later this year.',
#  'Hutchins agreed to plead guilty to distributing Kronos, a trojan that can be used to steal passwords and credentials from banking websites.',
#  'In recent years, the trojan has continued to spread.',
#  'He also agreed to plead guilty to a second count of conspiracy.',
# ...

# %%
#splitting fake article by \n
print("FAKE:")
split_fake = tokenize.sent_tokenize(fake)
split_fake
# Out:
# FAKE:
# ['Malware researcher Marcus Hutchins, who has been battling the FDA over his right to share top-level security information, has pleaded guilty to a charge related to software designed to spread malware.',
#  'Hutchins will spend two years and six months in prison for violating the Computer Fraud and Abuse Act, US Attorney Jeffery Castro announced.',
#  'As part of the plea deal, the nature of the malware found on Hutchins’ computer has been redacted.',
#  'To get around what is known as Hutchins’ A.I.',
#  'defense, Google is allowing the Department of Justice to redact the information.',
#  'An offer he initially made to the FDA then backed out of, according to Assistant US Attorney Micheal Furnall, was essentially a $75,000 fine and a one-year jail sentence on a serious bias crime charge, Furnall said.',
#  'If Hutchins had failed to comply with the deal, he’d face 30 years in prison, and he was sentenced to five years of supervised release, Furnall said.',
# ...

# %%
len(split_real)
# Out:
# 20

# %%
len(split_fake)
# Out:
# 24

# %%
#getting different length versions of real article

test_data_raw_real = []
for i in range(len(split_real)):
    data_real = []
    data_real = split_real[0:i+1]

    test_data_raw_real.append(data_real)

# %%
test_data_real = []
for temp in test_data_raw_real:
    curr_text = " ".join(temp)
    test_data_real.append(curr_text)

# %%
len(test_data_real)
# Out:
# 20

# %%
#getting different length versions of fake article

test_data_raw_fake = []
for i in range(len(split_fake)):
    data_fake = []
    data_fake = split_fake[0:i+1]

    test_data_raw_fake.append(data_fake)

# %%
test_data_fake = []
for temp in test_data_raw_fake:
    curr_text = " ".join(temp)
    test_data_fake.append(curr_text)

# %%
len(test_data_fake)
# Out:
# 24

# %%
#write real data to jsonl file with correct format
jsonFile = open("test_data1_real.jsonl", "w")

#delete text and set it to test_data_real[i], author should be a string, add "label": "human", and "split":"test"
for i in range(len(test_data_real)):
    new_dict = {"url":"https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","url_used":"https:\/\/web.archive.org\/web\/20190424064330id_\/https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","title":"Malware researcher Marcus Hutchins pleads guilty, ending his legal case \u2013 TechCrunch","text": test_data_real[i],"summary": "","authors":"","publish_date":"04-19-2019","domain":"techcrunch.com","warc_date":"20190424064330","status":"success_wayback","split":"test","label": "human","inst_index":24030}
    jsonString = json.dumps(new_dict)
    jsonFile.write(jsonString+"\n")
    

jsonFile.close()

# %%
#write fake data to jsonl file with correct format
jsonFile = open("test_data1_fake.jsonl", "w")

#delete text and set it to test_data_fake[i], author should be a string, add "label": "human", and "split":"test"
for i in range(len(test_data_fake)):
    new_dict = {"url":"https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","url_used":"https:\/\/web.archive.org\/web\/20190424064330id_\/https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","title":"Malware researcher Marcus Hutchins pleads guilty, ending his legal case \u2013 TechCrunch","text": test_data_fake[i],"summary": "","authors":"","publish_date":"04-19-2019","domain":"techcrunch.com","warc_date":"20190424064330","status":"success_wayback","split":"test","label": "human","inst_index":24030}
    jsonString = json.dumps(new_dict)
    jsonFile.write(jsonString+"\n")
    

jsonFile.close()

# %%
#1
new_dict = {"url":"https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","url_used":"https:\/\/web.archive.org\/web\/20190424064330id_\/https:\/\/techcrunch.com\/2019\/04\/19\/malwaretech-legal-case-over\/","title":"Malware researcher Marcus Hutchins pleads guilty, ending his legal case \u2013 TechCrunch","text": test_data[i],"summary":null,"authors":"","publish_date":"04-19-2019","domain":"techcrunch.com","warc_date":"20190424064330","status":"success_wayback","split":"test","label": "human","inst_index":24030}

# %%
#4
new_dict = {"title":"Fox and Friends Segment Suggests Climate Change is the Result of Friction","text": test_data[i],"summary":"Diamond and Silk told Fox News viewers that climate change is real\u2014but the result of the earth rotating.","authors":"Dave Holmes","publish_date":"04-05-2019","status":"success","url":"https:\/\/www.esquire.com\/news-politics\/a27056109\/fox-and-friends-diamond-and-silk-climate-change\/","domain":"esquire.com","warc_date":"2019-04-19T23:49:39Z","split":"test", "label": "human", "inst_index":51645}

# %%
#5
new_dict = {"title":"Did The High Court Just Pick Sides In the T-Series vs PewDiePie War, Banning Diss Tracks?","text": test_data[i],"summary":"Most \"sore loser\" on YouTube is the new battle!","authors":"Tanzim Pardiwalla","publish_date":"04-12-2019","status":"success","url":"https:\/\/in.mashable.com\/culture\/2952\/did-the-high-court-just-pick-sides-in-the-t-series-vs-pewdie","domain":"mashable.com","warc_date":"2019-04-24T16:40:00Z","split":"test", "label": "human" ,"inst_index":114627}

# %%
#6
new_dict = {"title":"Brexit: Corbyn told to back new EU referendum or lose millions of supporters","text": test_data[i],"summary":"A generation of young people could desert the party, says Richard Corbett, leader of Labour MEPs","authors":"Jon Cruddas","publish_date":"04-13-2019","status":"success","url":"https:\/\/www.theguardian.com\/politics\/2019\/apr\/13\/corbyn-told-back-eu-referendum-or-lose-millions-voters-brexit","domain":"theguardian.com","warc_date":"2019-04-18T10:30:54Z","split":"test", "label": "human", "inst_index":27053}

# %%
#7
new_dict = {"url":"https:\/\/www.theatlantic.com\/politics\/archive\/2019\/04\/how-key-aides-have-survived-trump-white-house\/587038\/","url_used":"https:\/\/web.archive.org\/web\/20190415131634id_\/https:\/\/www.theatlantic.com\/politics\/archive\/2019\/04\/how-key-aides-have-survived-trump-white-house\/587038\/?utm_source=feed","title":"A Survival Guide for the Trump White House","text": test_data[i], "summary":"Amid West Wing turnover that is \u201coff the charts,\u201d the survivors have mastered the art of praising the boss.","authors":"Peter Nicholas","publish_date":"04-14-2019","domain":"theatlantic.com","warc_date":"20190415131634","status":"success_wayback","split":"test", "label": "human", "inst_index":9201}

# %%
#8
new_dict = {"title":"Georgetown Students Vote to Add Fee for Slavery Reparations to Tuition","text": test_data[i],"summary":"They would pay $27 per semester toward a fund for the descendants of slaves sold in 1838.","authors":"Molly Olmstead","publish_date":"04-12-2019","status":"success","url":"https:\/\/slate.com\/news-and-politics\/2019\/04\/georgetown-students-reparations-fund-vote.html","domain":"slate.com","warc_date":"2019-04-25T16:22:51Z","split":"test","label":"human", "inst_index":127836}
